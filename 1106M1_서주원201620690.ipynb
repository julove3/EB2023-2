# %% [markdown]
# <a href="https://colab.research.google.com/github/julove3/EB2023-2/blob/main/1106M1_%EC%84%9C%EC%A3%BC%EC%9B%90201620690.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **데이터 불러오기 및 정보 확인**

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/sample_data/music.csv')
df1
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# ...

# %%
df2 = pd.read_excel('/content/sample_data/weather.xlsx')
df2
# Out:
#            날짜  평균기온  최저기온  최고기온
# 0  2022-06-01  22.1  16.2  28.6
# 1  2022-06-02  21.5  17.1  26.9
# 2  2022-06-03  24.5  18.7  32.6
# 3  2022-06-04  25.6  20.3  29.7
# 4  2022-06-05  22.7  20.2  27.0
# 5  2022-06-06  19.7  16.7  24.5
# 6  2022-06-07  20.6  15.1  25.1
# 7  2022-06-08  21.2  16.2  25.8
# 8  2022-06-09  20.9  18.5  24.5
# 9  2022-06-10  20.9  17.2  26.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 12 2022-06-13  23.6  19.6  29.2
# 13 2022-06-14  21.5  17.7  27.1
# 14 2022-06-15  17.5  14.9  20.1
# 15 2022-06-16  20.3  17.6  24.8
# 16 2022-06-17  22.5  16.5  28.1
# 17 2022-06-18  23.3  22.0  25.1
# 18 2022-06-19  23.4  22.3  25.1
# 19 2022-06-20  25.2  22.0  29.0
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 22 2022-06-23  24.3  23.3  26.4
# 23 2022-06-24  22.6  20.6  24.9
# 24 2022-06-25  26.0  21.5  30.5
# 25 2022-06-26  26.5  24.8  28.1
# 26 2022-06-27  26.8  25.4  28.1
# 27 2022-06-28  26.9  25.7  27.9
# ...

# %%
import pandas as pd
filename='/content/sample_data/music.csv'
df1 = pd.read_csv(filename)
df1
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 0        좋은날    아이유          1        솔로   2010-12-09              카카오엔터테인먼트
# 1    내가제일잘나가   2NE1          4        그룹   2011-06-24               YG엔터테인먼트
# 2      강남스타일     싸이          1        솔로   2012-07-15               YG엔터테인먼트
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 4        위아래   EXID          4        그룹   2014-08-27                  바나나컬쳐
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 10      뚜두뚜두   블랙핑크          4        그룹   2018-06-15               YG엔터테인먼트
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         13 non-null     object
#  1   singer        13 non-null     object
#  2   personnel     13 non-null     int64
#  3   sortation     13 non-null     object
#  4   release_date  13 non-null     object
#  5   agency        13 non-null     object
#  6   genre         13 non-null     object
#  7   type          13 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 960.0+ bytes

# %%
import pandas as pd
filename='/content/sample_data/weather.xlsx'
df2 = pd.read_excel(filename)
df2
# Out:
#            날짜  평균기온  최저기온  최고기온
# 0  2022-06-01  22.1  16.2  28.6
# 1  2022-06-02  21.5  17.1  26.9
# 2  2022-06-03  24.5  18.7  32.6
# 3  2022-06-04  25.6  20.3  29.7
# 4  2022-06-05  22.7  20.2  27.0
# 5  2022-06-06  19.7  16.7  24.5
# 6  2022-06-07  20.6  15.1  25.1
# 7  2022-06-08  21.2  16.2  25.8
# 8  2022-06-09  20.9  18.5  24.5
# 9  2022-06-10  20.9  17.2  26.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 12 2022-06-13  23.6  19.6  29.2
# 13 2022-06-14  21.5  17.7  27.1
# 14 2022-06-15  17.5  14.9  20.1
# 15 2022-06-16  20.3  17.6  24.8
# 16 2022-06-17  22.5  16.5  28.1
# 17 2022-06-18  23.3  22.0  25.1
# 18 2022-06-19  23.4  22.3  25.1
# 19 2022-06-20  25.2  22.0  29.0
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 22 2022-06-23  24.3  23.3  26.4
# 23 2022-06-24  22.6  20.6  24.9
# 24 2022-06-25  26.0  21.5  30.5
# 25 2022-06-26  26.5  24.8  28.1
# 26 2022-06-27  26.8  25.4  28.1
# 27 2022-06-28  26.9  25.7  27.9
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      30 non-null     datetime64[ns]
#  1   평균기온    30 non-null     float64
#  2   최저기온    30 non-null     float64
#  3   최고기온    30 non-null     float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 1.1 KB

# %% [markdown]
# **데이터 선택**

# %%
#df1 의 열 선택 - singer

df1['singer']
# Out:
# 0       아이유
# 1      2NE1
# 2        싸이
# 3      f(x)
# 4      EXID
# 5      러블리즈
# 6     방탄소년단
# 7      여자친구
# 8      레드벨벳
# 9       워너원
# 10     블랙핑크
# 11       있지
# 12    방탄소년단
# Name: singer, dtype: object

# %%
#df1 의 열 선택 - singer
df1.singer
# Out:
# 0       아이유
# 1      2NE1
# 2        싸이
# 3      f(x)
# 4      EXID
# 5      러블리즈
# 6     방탄소년단
# 7      여자친구
# 8      레드벨벳
# 9       워너원
# 10     블랙핑크
# 11       있지
# 12    방탄소년단
# Name: singer, dtype: object

# %%
#연습 : df1 의 열 선택 - personnel

df1['personnel']
df1.personnel
# Out:
# 0      1
# 1      4
# 2      1
# 3      5
# 4      4
# 5      8
# 6      7
# 7      6
# 8      5
# 9     11
# 10     4
# 11     5
# 12     7
# Name: personnel, dtype: int64

# %%
#df2 의 열 선택 - 평균기온

df2['평균기온']
# Out:
# 0     22.1
# 1     21.5
# 2     24.5
# 3     25.6
# 4     22.7
# 5     19.7
# 6     20.6
# 7     21.2
# 8     20.9
# 9     20.9
# 10    24.6
# 11    24.6
# 12    23.6
# 13    21.5
# 14    17.5
# 15    20.3
# 16    22.5
# 17    23.3
# 18    23.4
# 19    25.2
# 20    26.5
# 21    25.9
# 22    24.3
# 23    22.6
# 24    26.0
# 25    26.5
# 26    26.8
# 27    26.9
# 28    25.1
# 29    22.3
# Name: 평균기온, dtype: float64

# %%
#df2 의 열 선택 - 평균기온

df2.평균기온
# Out:
# 0     22.1
# 1     21.5
# 2     24.5
# 3     25.6
# 4     22.7
# 5     19.7
# 6     20.6
# 7     21.2
# 8     20.9
# 9     20.9
# 10    24.6
# 11    24.6
# 12    23.6
# 13    21.5
# 14    17.5
# 15    20.3
# 16    22.5
# 17    23.3
# 18    23.4
# 19    25.2
# 20    26.5
# 21    25.9
# 22    24.3
# 23    22.6
# 24    26.0
# 25    26.5
# 26    26.8
# 27    26.9
# 28    25.1
# 29    22.3
# Name: 평균기온, dtype: float64

# %%
#연습: df2 의 열 선택 - 최고기온

df2['최고기온']
df2.최고기온
# Out:
# 0     28.6
# 1     26.9
# 2     32.6
# 3     29.7
# 4     27.0
# 5     24.5
# 6     25.1
# 7     25.8
# 8     24.5
# 9     26.6
# 10    32.7
# 11    31.5
# 12    29.2
# 13    27.1
# 14    20.1
# 15    24.8
# 16    28.1
# 17    25.1
# 18    25.1
# 19    29.0
# 20    32.6
# 21    31.0
# 22    26.4
# 23    24.9
# 24    30.5
# 25    28.1
# 26    28.1
# 27    27.9
# 28    26.1
# 29    24.5
# Name: 최고기온, dtype: float64

# %%
#조건을 충족하는 행 선택: loc[]이용

df1.loc[df1['personnel']>=5]
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 11      달라달라     있지          5        그룹   2019-02-12              JYP엔터테인먼트
# 12  Dynamite  방탄소년단          7        그룹   2020-08-21                  빅히트뮤직
#
#    genre type
# 3     댄스   정규
# 5     댄스   EP
# 6    R&B   정규
# 7     댄스   EP
# 8     댄스   EP
# 9     댄스   EP
# 11    댄스   싱글
# 12    댄스   싱글

# %%
#연습 df1: 조건을 충족하는 행 선택: loc[]이용
# personnel이 5미만인 행은?

df1.loc[df1['personnel'] < 5]
# Out:
#       title singer  personnel sortation release_date     agency genre type
# 0       좋은날    아이유          1        솔로   2010-12-09  카카오엔터테인먼트   발라드   EP
# 1   내가제일잘나가   2NE1          4        그룹   2011-06-24   YG엔터테인먼트    댄스   싱글
# 2     강남스타일     싸이          1        솔로   2012-07-15   YG엔터테인먼트    힙합   정규
# 4       위아래   EXID          4        그룹   2014-08-27      바나나컬쳐    댄스   싱글
# 10     뚜두뚜두   블랙핑크          4        그룹   2018-06-15   YG엔터테인먼트    댄스   EP

# %%
#조건을 충족하는 행 선택: loc[]이용

df2.loc[df2['평균기온']>=25]
# Out:
#            날짜  평균기온  최저기온  최고기온
# 3  2022-06-04  25.6  20.3  29.7
# 19 2022-06-20  25.2  22.0  29.0
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 24 2022-06-25  26.0  21.5  30.5
# 25 2022-06-26  26.5  24.8  28.1
# 26 2022-06-27  26.8  25.4  28.1
# 27 2022-06-28  26.9  25.7  27.9
# 28 2022-06-29  25.1  24.4  26.1

# %%
#연습 df2: 조건을 충족하는 행 선택: loc[]이용
# 평균기온이 20 미만인 행은?

df2.loc[df2['평균기온'] < 20]
# Out:
#            날짜  평균기온  최저기온  최고기온
# 5  2022-06-06  19.7  16.7  24.5
# 14 2022-06-15  17.5  14.9  20.1

# %%
#조건을 충족하는 행에서 칼럼 선택: loc[]이용

df1.loc[df1['personnel']>=5,['singer','agency']]
# Out:
#    singer                 agency
# 3    f(x)               SM엔터테인먼트
# 5    러블리즈               울림엔터테인먼트
# 6   방탄소년단                  빅히트뮤직
# 7    여자친구                   쏘스뮤직
# 8    레드벨벳               SM엔터테인먼트
# 9     워너원  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 11     있지              JYP엔터테인먼트
# 12  방탄소년단                  빅히트뮤직

# %%
#연습 df1: 조건을 충족하는 행에서 칼럼 선택: loc[]이용
#Personnel 이 5 미만인 행 중 singer, personnel을 출력하세요.

df1.loc[df1['personnel'] < 5, ['singer', 'personnel']]
# Out:
#    singer  personnel
# 0     아이유          1
# 1    2NE1          4
# 2      싸이          1
# 4    EXID          4
# 10   블랙핑크          4

# %%
#조건을 충족하는 행에서 칼럼 선택: loc[]이용

df2.loc[df2['평균기온']>=25,['최저기온','최고기온']]
# Out:
#     최저기온  최고기온
# 3   20.3  29.7
# 19  22.0  29.0
# 20  21.2  32.6
# 21  21.9  31.0
# 24  21.5  30.5
# 25  24.8  28.1
# 26  25.4  28.1
# 27  25.7  27.9
# 28  24.4  26.1

# %%
#연습 df2: 조건을 충족하는 행에서 칼럼 선택: loc[]이용
#평균기온이 20미만인 행의 최고기온 칼럼 출력하기,

df2.loc[df2['평균기온'] < 20, ['최고기온']]
# Out:
#     최고기온
# 5   24.5
# 14  20.1

# %%
#특정 행의 여러 칼럼 (특정 인덱스 범위) 선택하기 : loc[] 이용

df1.loc[0:5, ['singer','personnel']]
# Out:
#   singer  personnel
# 0    아이유          1
# 1   2NE1          4
# 2     싸이          1
# 3   f(x)          5
# 4   EXID          4
# 5   러블리즈          8

# %%
#연습 df1: 특정 행의 여러 칼럼 선택하기 : loc[] 이용
# 인덱스 0에서 8 의 행에서 singer, agency 를 출력하세요.

df1.loc[0:8, ['singer', 'agency']]
# Out:
#   singer     agency
# 0    아이유  카카오엔터테인먼트
# 1   2NE1   YG엔터테인먼트
# 2     싸이   YG엔터테인먼트
# 3   f(x)   SM엔터테인먼트
# 4   EXID      바나나컬쳐
# 5   러블리즈   울림엔터테인먼트
# 6  방탄소년단      빅히트뮤직
# 7   여자친구       쏘스뮤직
# 8   레드벨벳   SM엔터테인먼트

# %%
#df2 특정 행의 여러 칼럼 선택하기 : loc[] 이용

df2.loc[0:3, ['날짜','최고기온']]
# Out:
#           날짜  최고기온
# 0 2022-06-01  28.6
# 1 2022-06-02  26.9
# 2 2022-06-03  32.6
# 3 2022-06-04  29.7

# %%
#연습 df2: 특정 행의 여러 칼럼 선택하기 : loc[] 이용
#인덱스 0에서 5까지 행의 날짜, 최저기온, 최고기온을 출력하세요.

df2.loc[0:5, ['날짜', '최저기온', '최고기온']]
# Out:
#           날짜  최저기온  최고기온
# 0 2022-06-01  16.2  28.6
# 1 2022-06-02  17.1  26.9
# 2 2022-06-03  18.7  32.6
# 3 2022-06-04  20.3  29.7
# 4 2022-06-05  20.2  27.0
# 5 2022-06-06  16.7  24.5

# %% [markdown]
# **불인덱싱**

# %%
#불인덱싱

w=df1['personnel']>=5
df1[w]
# Out:
#        title singer  personnel sortation release_date                 agency  \
# 3       첫사랑니   f(x)          5        그룹   2013-07-29               SM엔터테인먼트
# 5    Ah-Choo   러블리즈          8        그룹   2015-10-01               울림엔터테인먼트
# 6       피땀눈물  방탄소년단          7        그룹   2016-10-10                  빅히트뮤직
# 7     시간을달려서   여자친구          6        그룹   2016-01-25                   쏘스뮤직
# 8        빨간맛   레드벨벳          5        그룹   2017-07-09               SM엔터테인먼트
# 9       에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 11      달라달라     있지          5        그룹   2019-02-12              JYP엔터테인먼트
# 12  Dynamite  방탄소년단          7        그룹   2020-08-21                  빅히트뮤직
#
#    genre type
# 3     댄스   정규
# 5     댄스   EP
# 6    R&B   정규
# 7     댄스   EP
# 8     댄스   EP
# 9     댄스   EP
# 11    댄스   싱글
# 12    댄스   싱글

# %%
#불인덱싱에서 특정 칼럼 선택

w=df1['personnel']>=5
df1[w][['singer','agency']]
# Out:
#    singer                 agency
# 3    f(x)               SM엔터테인먼트
# 5    러블리즈               울림엔터테인먼트
# 6   방탄소년단                  빅히트뮤직
# 7    여자친구                   쏘스뮤직
# 8    레드벨벳               SM엔터테인먼트
# 9     워너원  YMC엔터테인먼트, 스톤뮤직엔터테인먼트
# 11     있지              JYP엔터테인먼트
# 12  방탄소년단                  빅히트뮤직

# %%
#연습 df1: 불인덱싱으로 personnel이 5 미만인 행의 singer, personnel 컬럼을 출력하세요.

w = df1['personnel'] < 5
df1[w][['singer', 'personnel']]
# Out:
#    singer  personnel
# 0     아이유          1
# 1    2NE1          4
# 2      싸이          1
# 4    EXID          4
# 10   블랙핑크          4

# %%
#불인덱싱 - 조건에 맞는 데이터 선택
#데이터 중 인원수가 가장 많은 그룹의 음반 정보를 출력하세요.
w=df1['personnel']==df1['personnel'].max()
df1[w]
# Out:
#   title singer  personnel sortation release_date                 agency genre  \
# 9  에너제틱    워너원         11        그룹   2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트    댄스
#
#   type
# 9   EP

# %%
#불인덱싱 - 조건에 맞는 데이터 선택
#데이터 중 인원수가 가장 적은 그룹의 음반 정보를 출력하세요.
w=df1['personnel']==df1['personnel'].min()
df1[w]
# Out:
#    title singer  personnel sortation release_date     agency genre type
# 0    좋은날    아이유          1        솔로   2010-12-09  카카오엔터테인먼트   발라드   EP
# 2  강남스타일     싸이          1        솔로   2012-07-15   YG엔터테인먼트    힙합   정규

# %%
#연습 df1
#데이터 중 인원수가 가장 적은 그룹의 singer,  release_date, agency 정보를 출력하세요

w = df1['personnel'] == df1['personnel'].min()
df1[w][['singer', 'release_date', 'agency']]
# Out:
#   singer release_date     agency
# 0    아이유   2010-12-09  카카오엔터테인먼트
# 2     싸이   2012-07-15   YG엔터테인먼트

# %%
#불인덱싱 df2의 자료에서 특정 조건의 데이터 출력
v=df2['평균기온']>=25
df2[v]
# Out:
#            날짜  평균기온  최저기온  최고기온
# 3  2022-06-04  25.6  20.3  29.7
# 19 2022-06-20  25.2  22.0  29.0
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 24 2022-06-25  26.0  21.5  30.5
# 25 2022-06-26  26.5  24.8  28.1
# 26 2022-06-27  26.8  25.4  28.1
# 27 2022-06-28  26.9  25.7  27.9
# 28 2022-06-29  25.1  24.4  26.1

# %%
#불인덱싱 df2의 자료에서 특정 조건의 데이터 출력 시 출력 컬럼 지정
v=df2['평균기온']>=25
df2[v][['최고기온','최저기온']]
# Out:
#     최고기온  최저기온
# 3   29.7  20.3
# 19  29.0  22.0
# 20  32.6  21.2
# 21  31.0  21.9
# 24  30.5  21.5
# 25  28.1  24.8
# 26  28.1  25.4
# 27  27.9  25.7
# 28  26.1  24.4

# %%
#최고로 더웠던 날의 데이터 출력
v=df2['최고기온']==df2['최고기온'].max()
df2[v]
# Out:
#            날짜  평균기온  최저기온  최고기온
# 10 2022-06-11  24.6  17.7  32.7

# %%
#연습 - 온도가 최저기온이었던 날의 데이터는? .max() 대신 .mim(), 최고기온 대신 최저기온 입력

v = df2['최저기온'] == df2['최저기온'].min()
df2[v]
# Out:
#            날짜  평균기온  최저기온  최고기온
# 14 2022-06-15  17.5  14.9  20.1

# %%
#일교차가 10° 이상인 데이터를 출력.
v=df2['최고기온']-df2['최저기온']>=10
df2[v]
# Out:
#            날짜  평균기온  최저기온  최고기온
# 0  2022-06-01  22.1  16.2  28.6
# 2  2022-06-03  24.5  18.7  32.6
# 6  2022-06-07  20.6  15.1  25.1
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 16 2022-06-17  22.5  16.5  28.1
# 20 2022-06-21  26.5  21.2  32.6

# %%
#연습 - 일교차가 5° 이상인 데이터를 출력.

v = df2['최고기온'] - df2['최저기온'] >= 5
df2[v]
# Out:
#            날짜  평균기온  최저기온  최고기온
# 0  2022-06-01  22.1  16.2  28.6
# 1  2022-06-02  21.5  17.1  26.9
# 2  2022-06-03  24.5  18.7  32.6
# 3  2022-06-04  25.6  20.3  29.7
# 4  2022-06-05  22.7  20.2  27.0
# 5  2022-06-06  19.7  16.7  24.5
# 6  2022-06-07  20.6  15.1  25.1
# 7  2022-06-08  21.2  16.2  25.8
# 8  2022-06-09  20.9  18.5  24.5
# 9  2022-06-10  20.9  17.2  26.6
# 10 2022-06-11  24.6  17.7  32.7
# 11 2022-06-12  24.6  18.9  31.5
# 12 2022-06-13  23.6  19.6  29.2
# 13 2022-06-14  21.5  17.7  27.1
# 14 2022-06-15  17.5  14.9  20.1
# 15 2022-06-16  20.3  17.6  24.8
# 16 2022-06-17  22.5  16.5  28.1
# 19 2022-06-20  25.2  22.0  29.0
# 20 2022-06-21  26.5  21.2  32.6
# 21 2022-06-22  25.9  21.9  31.0
# 24 2022-06-25  26.0  21.5  30.5

# %% [markdown]
# **데이터 가공하기**

# %%
#엑셀 파일 형식의 music 데이터 불러오기
#데이터 프레임 이름을 df3으로 지정
import pandas as pd
filename='/content/sample_data/music_.xlsx'
df3=pd.read_excel(filename)
df3.head()
# Out:
#      title singer  personnel sortation release_date     agency genre type
# 0      좋은날    아이유          1        솔로   2010-12-09  카카오엔터테인먼트   발라드   EP
# 1  내가제일잘나가   2NE1          4        그룹   2011-06-24   YG엔터테인먼트    댄스   싱글
# 2    강남스타일     싸이          1        솔로   2012-07-15   YG엔터테인먼트    힙합   정규
# 3     첫사랑니   f(x)          5        그룹   2013-07-29   SM엔터테인먼트    댄스   정규
# 4      위아래   EXID          4        그룹   2014-08-27      바나나컬쳐    댄스   싱글

# %%
#가공할 데이터 상위 5행 출력
df3.head()
# Out:
#      title singer  personnel sortation release_date     agency genre type
# 0      좋은날    아이유          1        솔로   2010-12-09  카카오엔터테인먼트   발라드   EP
# 1  내가제일잘나가   2NE1          4        그룹   2011-06-24   YG엔터테인먼트    댄스   싱글
# 2    강남스타일     싸이          1        솔로   2012-07-15   YG엔터테인먼트    힙합   정규
# 3     첫사랑니   f(x)          5        그룹   2013-07-29   SM엔터테인먼트    댄스   정규
# 4      위아래   EXID          4        그룹   2014-08-27      바나나컬쳐    댄스   싱글

# %%
#데이터 컬럼 이름 확인
df3.columns
# Out:
# Index(['title', 'singer', 'personnel', 'sortation', 'release_date', 'agency',
#        'genre', 'type'],
#       dtype='object')

# %%
#컬럼 (변수) 삭제

df3.drop(['sortation'], axis=1, inplace=True)
df3.columns
# Out:
# Index(['title', 'singer', 'personnel', 'release_date', 'agency', 'genre',
#        'type'],
#       dtype='object')

# %%
#컬럼 이름 변경
df3.columns=['제목','이름','인원수','발매일','기획사','장르','유형']
df3.head()
# Out:
#         제목    이름  인원수        발매일        기획사   장르  유형
# 0      좋은날   아이유    1 2010-12-09  카카오엔터테인먼트  발라드  EP
# 1  내가제일잘나가  2NE1    4 2011-06-24   YG엔터테인먼트   댄스  싱글
# 2    강남스타일    싸이    1 2012-07-15   YG엔터테인먼트   힙합  정규
# 3     첫사랑니  f(x)    5 2013-07-29   SM엔터테인먼트   댄스  정규
# 4      위아래  EXID    4 2014-08-27      바나나컬쳐   댄스  싱글

# %% [markdown]
# **데이터 가공 - 컬럼 생성**

# %%
#csv 파일의 컬럼 데이터 타입 확인
df1.dtypes
# Out:
# title           object
# singer          object
# personnel        int64
# sortation       object
# release_date    object
# agency          object
# genre           object
# type            object
# dtype: object

# %%
#엑셀 파일의 컬럼 데이터 타입 확인
df3.dtypes
# Out:
# 제목             object
# 이름             object
# 인원수             int64
# 발매일    datetime64[ns]
# 기획사            object
# 장르             object
# 유형             object
# dtype: object

# %%
# df3 새로운 컬럼 생성하기 : 년도,월,일 - 엑셀파일
df3['년도']=df3['발매일'].dt.year
df3['월']=df3['발매일'].dt.month
df3['일']=df3['발매일'].dt.day
df3.head()
# Out:
#         제목    이름  인원수        발매일        기획사   장르  유형    년도   월   일
# 0      좋은날   아이유    1 2010-12-09  카카오엔터테인먼트  발라드  EP  2010  12   9
# 1  내가제일잘나가  2NE1    4 2011-06-24   YG엔터테인먼트   댄스  싱글  2011   6  24
# 2    강남스타일    싸이    1 2012-07-15   YG엔터테인먼트   힙합  정규  2012   7  15
# 3     첫사랑니  f(x)    5 2013-07-29   SM엔터테인먼트   댄스  정규  2013   7  29
# 4      위아래  EXID    4 2014-08-27      바나나컬쳐   댄스  싱글  2014   8  27

# %%
# df1 새로운 컬럼 생성하기 : 년도,월,일 - csv 파일
#오류 확인
df1['년도']=df1['발매일'].dt.year
df1['월']=df1['발매일'].dt.month
df1['일']=df1['발매일'].dt.day
df1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '발매일'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# 가공된 전체 파일 확인
df3
# Out:
#           제목     이름  인원수        발매일                    기획사   장르  유형    년도   월  \
# 0        좋은날    아이유    1 2010-12-09              카카오엔터테인먼트  발라드  EP  2010  12
# 1    내가제일잘나가   2NE1    4 2011-06-24               YG엔터테인먼트   댄스  싱글  2011   6
# 2      강남스타일     싸이    1 2012-07-15               YG엔터테인먼트   힙합  정규  2012   7
# 3       첫사랑니   f(x)    5 2013-07-29               SM엔터테인먼트   댄스  정규  2013   7
# 4        위아래   EXID    4 2014-08-27                  바나나컬쳐   댄스  싱글  2014   8
# 5    Ah-Choo   러블리즈    8 2015-10-01               울림엔터테인먼트   댄스  EP  2015  10
# 6       피땀눈물  방탄소년단    7 2016-10-10                  빅히트뮤직  R&B  정규  2016  10
# 7     시간을달려서   여자친구    6 2016-01-25                   쏘스뮤직   댄스  EP  2016   1
# 8        빨간맛   레드벨벳    5 2017-07-09               SM엔터테인먼트   댄스  EP  2017   7
# 9       에너제틱    워너원   11 2017-08-07  YMC엔터테인먼트, 스톤뮤직엔터테인먼트   댄스  EP  2017   8
# 10      뚜두뚜두   블랙핑크    4 2018-06-15               YG엔터테인먼트   댄스  EP  2018   6
# ...

# %% [markdown]
# **데이터 그룹핑**

# %%
df4=df3.groupby('장르').count()
df4
# Out:
#      제목  이름  인원수  발매일  기획사  유형  년도   월   일
# 장르
# R&B   1   1    1    1    1   1   1   1   1
# 댄스   10  10   10   10   10  10  10  10  10
# 발라드   1   1    1    1    1   1   1   1   1
# 힙합    1   1    1    1    1   1   1   1   1

# %%
# 데이터 프레임 제목 변경. 인원수 -> 자료수

df4.columns=['제목','이름','자료수','발매일','기획사','유형','년도','월','일']
df4.columns
# Out:
# Index(['제목', '이름', '자료수', '발매일', '기획사', '유형', '년도', '월', '일'], dtype='object')

# %%
# 데이터 프레임에서 자료수만 출력하기.

pd.DataFrame(df4['자료수'])
# Out:
#      자료수
# 장르
# R&B    1
# 댄스    10
# 발라드    1
# 힙합     1

# %%
# 장르, 유형별  자료 수 합계
df5=df3.groupby(['장르','유형']).count()
df5
# Out:
#         제목  이름  인원수  발매일  기획사  년도  월  일
# 장르  유형
# R&B 정규   1   1    1    1    1   1  1  1
# 댄스  EP   5   5    5    5    5   5  5  5
#     싱글   4   4    4    4    4   4  4  4
#     정규   1   1    1    1    1   1  1  1
# 발라드 EP   1   1    1    1    1   1  1  1
# 힙합  정규   1   1    1    1    1   1  1  1

# %%
#연습 - df5의 컬럼 이름 변경. 인원수 -> 자료수

df5.columns = ['제목', '이름', '자료수', '발매일', '기획사', '년도', '월', '일']
df5.columns
# Out:
# Index(['제목', '이름', '자료수', '발매일', '기획사', '년도', '월', '일'], dtype='object')

# %%
#연습 - df5에서 자료수만 출력.

pd.DataFrame(df5['자료수'])
# Out:
#         자료수
# 장르  유형
# R&B 정규    1
# 댄스  EP    5
#     싱글    4
#     정규    1
# 발라드 EP    1
# 힙합  정규    1
