# %% [markdown]
# <a href="https://colab.research.google.com/github/julove3/EB2023-2/blob/main/%EC%84%9C%EC%A3%BC%EC%9B%90_201620690.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **데이터프레임 형성 연습**

# %%
import pandas as pd

# %%
#데이터 프레임 형성
df1=pd.DataFrame({'지역':['부천','서울','대전','춘천'],
                 '풍속(m/s)':[1,1.5,2,3],
                 '온도(°C)':[15,13,10,8],
                 '습도(%)':[64,62,63,65],
                 '기압(hPa)':[1022,1022,1022,1022],})

df1
# Out:
#    지역  풍속(m/s)  온도(°C)  습도(%)  기압(hPa)
# 0  부천      1.0      15     64     1022
# 1  서울      1.5      13     62     1022
# 2  대전      2.0      10     63     1022
# 3  춘천      3.0       8     65     1022

# %%
#컬럼별 자료 값 확인
df1.dtypes
# Out:
# 지역          object
# 풍속(m/s)    float64
# 온도(°C)       int64
# 습도(%)        int64
# 기압(hPa)      int64
# dtype: object

# %%
#df1 의 온도 최고값 확인
df1['온도(°C)'].max()
# Out:
# 15

# %%
#df1 의 온도 최고값 행 출력
a=df1['온도(°C)']==df1['온도(°C)'].max()
df1[a]
# Out:
#    지역  풍속(m/s)  온도(°C)  습도(%)  기압(hPa)
# 0  부천      1.0      15     64     1022

# %%
#df1 의 온도 최고값 행 출력
a=df1['온도(°C)']=df1['온도(°C)'].max()
df1[a]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 15
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#연습 - 데이터 프레임 형성
#지역 부천, 인천, 전주, 창원 입력
#풍속 1.5, 2, 1, 1.8 입력

df2=pd.DataFrame({'지역':['부천', '인천', '전주', '창원'],
                 '풍속(m/s)':[1.5, 2, 1, 1.8],
                 '온도(°C)':[15,13,11,9]})

df2
# Out:
#    지역  풍속(m/s)  온도(°C)
# 0  부천      1.5      15
# 1  인천      2.0      13
# 2  전주      1.0      11
# 3  창원      1.8       9

# %%
#연습 - df2 컬럼별 자료 값 확인
df2.dtypes
# Out:
# 지역          object
# 풍속(m/s)    float64
# 온도(°C)       int64
# dtype: object

# %%
#연습 - df2 의 풍속(m/s) 최소값 확인
df2['풍속(m/s)'].min()
# Out:
# 1.0

# %%
#연습 - df2 의 온도 최소값 행 출력
#.min() 활용
df2['온도(°C)'].min()
# Out:
# 9

# %% [markdown]
# **Pandas 활용 - Seaborn Dataset 으로**

# %% [markdown]
# 데이터 분류 및 가공

# %%
import seaborn as sns

# Get a list of available datasets
dataset_names = sns.get_dataset_names()

# Print the list of dataset names
print(dataset_names)
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
import pandas as pd
import seaborn as sns

# Load the 'seaice' dataset instead of 'tips'
seaice = sns.load_dataset('seaice')
#Extent unit: 10^6 km^2
print(seaice)
# Out:
#             Date  Extent
# 0     1980-01-01  14.200
# 1     1980-01-03  14.302
# 2     1980-01-05  14.414
# 3     1980-01-07  14.518
# 4     1980-01-09  14.594
# ...          ...     ...
# 13170 2019-12-27  12.721
# 13171 2019-12-28  12.712
# 13172 2019-12-29  12.780
# 13173 2019-12-30  12.858
# 13174 2019-12-31  12.889
#
# [13175 rows x 2 columns]

# %%
import pandas as pd
import seaborn as sns

penguins = sns.load_dataset('penguins')

print(penguins)
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# penguins 데이터의 상위 10개 출력

penguins.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# ...

# %%
# 부리 길이 55 이상 출력
penguins[penguins['bill_length_mm']>=55]
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 169  Chinstrap   Dream            58.0           17.8              181.0
# 215  Chinstrap   Dream            55.8           19.8              207.0
# 253     Gentoo  Biscoe            59.6           17.0              230.0
# 321     Gentoo  Biscoe            55.9           17.0              228.0
# 335     Gentoo  Biscoe            55.1           16.0              230.0
#
#      body_mass_g     sex
# 169       3700.0  Female
# 215       4000.0    Male
# 253       6050.0    Male
# 321       5600.0    Male
# 335       5850.0    Male

# %%
# 연습 - 지느러미길이 180 미만 출력
penguins[penguins['flipper_length_mm'] < 180]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20      Adelie     Biscoe            37.8           18.3              174.0
# 28      Adelie     Biscoe            37.9           18.6              172.0
# 30      Adelie      Dream            39.5           16.7              178.0
# 31      Adelie      Dream            37.2           18.1              178.0
# 47      Adelie      Dream            37.5           18.9              179.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 122     Adelie  Torgersen            40.2           17.0              176.0
# 158  Chinstrap      Dream            46.1           18.2              178.0
#
#      body_mass_g     sex
# 20        3400.0  Female
# 28        3150.0  Female
# 30        3250.0  Female
# 31        3900.0    Male
# 47        2975.0     NaN
# 98        2900.0  Female
# 122       3450.0  Female
# 158       3250.0  Female

# %%
# 연습 - 지느러미길이 200 이상 출력, 상위 3행만
penguins[penguins['flipper_length_mm'] >= 200].head(3)
# Out:
#    species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 53  Adelie  Biscoe            42.0           19.5              200.0
# 90  Adelie   Dream            35.7           18.0              202.0
# 91  Adelie   Dream            41.1           18.1              205.0
#
#     body_mass_g     sex
# 53       4050.0    Male
# 90       3550.0  Female
# 91       4300.0    Male

# %%
#자료 중 "성별: 암컷" 혹은 "서식지: Dream"에 해당하는 자료 추출
#합집합의 개념

penguins[penguins['sex'] == 'Female']
penguins[penguins['island'] == 'Dream']














penguins[penguins['sex']=='Female']
penguins[penguins['island']=='Dream']
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30      Adelie  Dream            39.5           16.7              178.0
# 31      Adelie  Dream            37.2           18.1              178.0
# 32      Adelie  Dream            39.5           17.8              188.0
# 33      Adelie  Dream            40.9           18.9              184.0
# 34      Adelie  Dream            36.4           17.0              195.0
# ..         ...    ...             ...            ...                ...
# 215  Chinstrap  Dream            55.8           19.8              207.0
# 216  Chinstrap  Dream            43.5           18.1              202.0
# 217  Chinstrap  Dream            49.6           18.2              193.0
# 218  Chinstrap  Dream            50.8           19.0              210.0
# 219  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex
# 30        3250.0  Female
# 31        3900.0    Male
# ...

# %%
#자료 중 "성별: 암컷" 이면서 "서식지: Dream"에 해당하는 자료 추출
#교집합의 개념

conditions=(penguins['sex'] == 'Female') & (penguins['island'] == 'Dream')
penguins[conditions].head()










conditions=(penguins['sex']=='Female') & (penguins['island']=='Dream')
penguins[conditions].head()
# Out:
#    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30  Adelie  Dream            39.5           16.7              178.0
# 32  Adelie  Dream            39.5           17.8              188.0
# 34  Adelie  Dream            36.4           17.0              195.0
# 37  Adelie  Dream            42.2           18.5              180.0
# 38  Adelie  Dream            37.6           19.3              181.0
#
#     body_mass_g     sex
# 30       3250.0  Female
# 32       3300.0  Female
# 34       3325.0  Female
# 37       3550.0  Female
# 38       3300.0  Female

# %%
#"가장 무거운 펭귄"을 추출하는 방법
penguins[penguins['body_mass_g'].max()==penguins['body_mass_g']]
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 237  Gentoo  Biscoe            49.2           15.2              221.0
#
#      body_mass_g   sex
# 237       6300.0  Male

# %%
#연습 - 가장 가벼운 펭귄 추출.
#.min() 함수 사용
penguins[penguins['body_mass_g'] == penguins['body_mass_g'].min()]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 190  Chinstrap  Dream            46.9           16.6              192.0
#
#      body_mass_g     sex
# 190       2700.0  Female

# %%
# 펭귄 몸무게 내림차순 정렬, 상위 10개 출력

penguins.sort_values('body_mass_g', ascending = False).head(10)
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 237  Gentoo  Biscoe            49.2           15.2              221.0
# 253  Gentoo  Biscoe            59.6           17.0              230.0
# 297  Gentoo  Biscoe            51.1           16.3              220.0
# 337  Gentoo  Biscoe            48.8           16.2              222.0
# 331  Gentoo  Biscoe            49.8           15.9              229.0
# 299  Gentoo  Biscoe            45.2           16.4              223.0
# 335  Gentoo  Biscoe            55.1           16.0              230.0
# 235  Gentoo  Biscoe            49.3           15.7              217.0
# 233  Gentoo  Biscoe            48.4           14.6              213.0
# 295  Gentoo  Biscoe            48.6           16.0              230.0
#
#      body_mass_g   sex  body_mass_kg  flipper_length_m
# 237       6300.0  Male          6.30             0.221
# 253       6050.0  Male          6.05             0.230
# ...

# %%
#연습 - 펭귄 몸무게 오름차순 정렬, 상위 10개 출력
penguins.sort_values('body_mass_g', ascending = True).head(10)
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 190  Chinstrap      Dream            46.9           16.6              192.0
# 64      Adelie     Biscoe            36.4           17.1              184.0
# 58      Adelie     Biscoe            36.5           16.6              181.0
# 116     Adelie  Torgersen            38.6           17.0              188.0
# 98      Adelie      Dream            33.1           16.1              178.0
# 54      Adelie     Biscoe            34.5           18.1              187.0
# 174  Chinstrap      Dream            43.2           16.6              187.0
# 104     Adelie     Biscoe            37.9           18.6              193.0
# 47      Adelie      Dream            37.5           18.9              179.0
# 44      Adelie      Dream            37.0           16.9              185.0
#
#      body_mass_g     sex  body_mass_kg  flipper_length_m
# 190       2700.0  Female         2.700             0.192
# ...

# %%
# 펭귄 몸무게 kg 단위로 출력
#상위 5개만 출력
penguins['body_mass_kg']=penguins['body_mass_g']/1000
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  body_mass_kg  flipper_length_m
# 0       3750.0    Male          3.75             0.181
# 1       3800.0  Female          3.80             0.186
# 2       3250.0  Female          3.25             0.195
# 3          NaN     NaN           NaN               NaN
# 4       3450.0  Female          3.45             0.193

# %%
# 연습 - 펭귄 지느러미 m 단위로 출력
# 상위 5개 출력
penguins['flipper_length_m'] = penguins['flipper_length_mm']/1000
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  body_mass_kg  flipper_length_m
# 0       3750.0    Male          3.75             0.181
# 1       3800.0  Female          3.80             0.186
# 2       3250.0  Female          3.25             0.195
# 3          NaN     NaN           NaN               NaN
# 4       3450.0  Female          3.45             0.193

# %%
#종별로 몸무게 평균 출력
pd.DataFrame(penguins.groupby('species')['body_mass_kg'].mean())
# Out:
#            body_mass_kg
# species
# Adelie         3.700662
# Chinstrap      3.733088
# Gentoo         5.076016

# %%
#연습 - 서식지별 지느러미 길이 평균 출력
pd.DataFrame(penguins.groupby('island').mean()['flipper_length_mm'])
# Out:
# <ipython-input-97-f32553918d75>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   pd.DataFrame(penguins.groupby('island').mean()['flipper_length_mm'])
#            flipper_length_mm
# island
# Biscoe            209.706587
# Dream             193.072581
# Torgersen         191.196078

# %%
# 펭귄 데이터세트 전체에서 species 컬럼의 Adelie와 Gentoo만 필터링 후 출력
# 특정 조건 선택 시 isin함수를 사용
conditions=penguins['species'].isin(['Adelie','Gentoo'])
penguins[conditions]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  body_mass_kg  flipper_length_m
# ...

# %%
# 연습 - 펭귄 데이터세트 전체에서 서식지 Deream만 필터링 후 출력
# 특정 조건 선택 시 isin함수를 사용
# 상위 5개 컬럼만 출력
condition = penguins['island'].isin(['Dream'])
penguins[condition].head()
# Out:
#    species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 30  Adelie  Dream            39.5           16.7              178.0
# 31  Adelie  Dream            37.2           18.1              178.0
# 32  Adelie  Dream            39.5           17.8              188.0
# 33  Adelie  Dream            40.9           18.9              184.0
# 34  Adelie  Dream            36.4           17.0              195.0
#
#     body_mass_g     sex  body_mass_kg  flipper_length_m
# 30       3250.0  Female         3.250             0.178
# 31       3900.0    Male         3.900             0.178
# 32       3300.0  Female         3.300             0.188
# 33       3900.0    Male         3.900             0.184
# 34       3325.0  Female         3.325             0.195

# %%
#전체 펭귄 데이터의 몸무게 평균 출력
mean_mass=penguins['body_mass_kg'].mean()
mean_mass
# Out:
# 4.201754385964913

# %%
#연습 - 전체 펭귄 데이터의 지느러미 길이 평균 출력
mean_mass = penguins['flipper_length_mm'].mean()
mean_mass
# Out:
# 200.91520467836258

# %%
# 몸무게가 전체 펭귄 몸무게 평균보다 많은 데이터만 필터링.
penguins[penguins['body_mass_kg']>=penguins['body_mass_kg'].mean()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# 17   Adelie  Torgersen            42.5           20.7              197.0
# 39   Adelie      Dream            39.8           19.1              184.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  body_mass_kg  flipper_length_m
# ...

# %%
# 연습 - 지느러미 길이가 전체 펭귄 지느러미 길이 평균보다 많은 데이터만 필터링.
# 상위 5개 출력
penguins[penguins['flipper_length_mm'] > penguins['flipper_length_mm'].mean()].head()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 90   Adelie      Dream            35.7           18.0              202.0
# 91   Adelie      Dream            41.1           18.1              205.0
# 95   Adelie      Dream            40.8           18.9              208.0
# 101  Adelie     Biscoe            41.0           20.0              203.0
# 123  Adelie  Torgersen            41.4           18.5              202.0
#
#      body_mass_g     sex  body_mass_kg  flipper_length_m
# 90        3550.0  Female         3.550             0.202
# 91        4300.0    Male         4.300             0.205
# 95        4300.0    Male         4.300             0.208
# 101       4725.0    Male         4.725             0.203
# 123       3875.0    Male         3.875             0.202

# %%
#선택적 컬럼 출력 - species, island, bodymass (kg) 만 출력
penguins[['species','island','body_mass_kg']]
# Out:
#     species     island  body_mass_kg
# 0    Adelie  Torgersen          3.75
# 1    Adelie  Torgersen          3.80
# 2    Adelie  Torgersen          3.25
# 3    Adelie  Torgersen           NaN
# 4    Adelie  Torgersen          3.45
# ..      ...        ...           ...
# 339  Gentoo     Biscoe           NaN
# 340  Gentoo     Biscoe          4.85
# 341  Gentoo     Biscoe          5.75
# 342  Gentoo     Biscoe          5.20
# 343  Gentoo     Biscoe          5.40
#
# [344 rows x 3 columns]

# %%
# 연습 - 선택적 컬럼 출력 - bill_depth_mm,	flipper_length_mm,	body_mass_g만 출력

penguins[['bill_depth_mm', 'flipper_length_mm', 'body_mass_g']]
# Out:
#      bill_depth_mm  flipper_length_mm  body_mass_g
# 0             18.7              181.0       3750.0
# 1             17.4              186.0       3800.0
# 2             18.0              195.0       3250.0
# 3              NaN                NaN          NaN
# 4             19.3              193.0       3450.0
# ..             ...                ...          ...
# 339            NaN                NaN          NaN
# 340           14.3              215.0       4850.0
# 341           15.7              222.0       5750.0
# 342           14.8              212.0       5200.0
# 343           16.1              213.0       5400.0
#
# [344 rows x 3 columns]

# %%
# 몸무게가 적은 순서대로 10개의 행 출력
# species, island, bodymass (kg) 만 출력

penguins[['species','island','body_mass_kg']].sort_values('body_mass_kg',ascending=True).head(10)
# Out:
#        species     island  body_mass_kg
# 190  Chinstrap      Dream         2.700
# 64      Adelie     Biscoe         2.850
# 58      Adelie     Biscoe         2.850
# 116     Adelie  Torgersen         2.900
# 98      Adelie      Dream         2.900
# 54      Adelie     Biscoe         2.900
# 174  Chinstrap      Dream         2.900
# 104     Adelie     Biscoe         2.925
# 47      Adelie      Dream         2.975
# 44      Adelie      Dream         3.000

# %% [markdown]
# 결측데이터 처리

# %%
#결측데이터 확인- body_mass_kg 컬럼

penguins[penguins['body_mass_kg'].isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  body_mass_kg  flipper_length_m
# 3            NaN  NaN           NaN               NaN
# 339          NaN  NaN           NaN               NaN

# %%
# 컬럼별 결측데이터 개수 확인
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# body_mass_kg          2
# flipper_length_m      2
# dtype: int64

# %%
#결측데이터 확인- body_mass_kg 컬럼

penguins[penguins['sex'].isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 47   Adelie      Dream            37.5           18.9              179.0
# 246  Gentoo     Biscoe            44.5           14.3              216.0
# 286  Gentoo     Biscoe            46.2           14.4              214.0
# 324  Gentoo     Biscoe            47.3           13.8              216.0
# 336  Gentoo     Biscoe            44.5           15.7              217.0
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  sex  body_mass_kg  flipper_length_m
# ...

# %%
#drop 함수 이용
#Sex 컬럼 전체 삭제

penguins.drop('sex',axis=1,inplace=True)

# %%
#컬럼 이름 확인
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'body_mass_kg', 'flipper_length_m'],
#       dtype='object')

# %%
#삭제된 데이터 프레임 확인

penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g  body_mass_kg  flipper_length_m
# 0       3750.0          3.75             0.181
# 1       3800.0          3.80             0.186
# 2       3250.0          3.25             0.195
# 3          NaN           NaN               NaN
# 4       3450.0          3.45             0.193

# %%
# mass(kg) 의 최빈값 찾은 후 결측데이터에 대체
penguins['body_mass_kg'].mode()
# Out:
# 0    3.8
# Name: body_mass_kg, dtype: float64

# %%
# mass(kg) 컬럼의 결측데이터를 인덱싱 0 값 3.8로 대체
# 결측데이터가 존재했던 3번 확인

penguins['body_mass_kg'].fillna(penguins['body_mass_kg'].mode()[0],inplace=True)
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g  body_mass_kg  flipper_length_m
# 0       3750.0          3.75             0.181
# 1       3800.0          3.80             0.186
# 2       3250.0          3.25             0.195
# 3          NaN          3.80               NaN
# 4       3450.0          3.45             0.193

# %%
#body_mass_kg 결측데이터 행 확인
penguins[penguins['body_mass_kg'].isna()]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, body_mass_kg, flipper_length_m]
# Index: []

# %%
# 결측데이터가 존재했던 339번 확인
penguins.loc[339, 'body_mass_kg']
# Out:
# 3.8

# %%
# body_mass_kg 결측데이터가 대체된 데이터 프레임의 전체 결측데이터 확인

penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       2
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# body_mass_kg         0
# flipper_length_m     2
# dtype: int64

# %%
# 연습 - bill_length_mm 결측데이터 행 확인
penguins[penguins['bill_length_mm'].isna()]
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 339  Gentoo     Biscoe             NaN            NaN                NaN
#
#      body_mass_g  body_mass_kg  flipper_length_m
# 3            NaN           3.8               NaN
# 339          NaN           3.8               NaN

# %%
# 연습 - bill_length_mm 의 최빈값 찾은 후 결측데이터에 대체
#1. 최빈값 찾기

penguins['bill_length_mm'].mode()
# Out:
# 0    41.1
# Name: bill_length_mm, dtype: float64

# %%
# 연습 - bill_length_mm 컬럼의 결측데이터를 최빈값으로 대체
#2, 최빈값으로 결측데이터 대체

penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mode()[0], inplace = True)















penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mode()[0],inplace=True)

# %%
# 연습 - 결측데이터 행 확인
penguins[penguins['bill_length_mm'].isna()]
# Out:
# Empty DataFrame
# Columns: [species, island, bill_length_mm, bill_depth_mm, flipper_length_mm, body_mass_g, body_mass_kg, flipper_length_m]
# Index: []

# %%
# 연습 - bill_length_mm 결측데이터가 대체된 데이터 프레임의 전체 결측데이터 확인

penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# body_mass_kg         0
# flipper_length_m     2
# dtype: int64

# %%
#ChatGPT 로 시각화 코드 형성
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the 'penguins' dataset
penguins = sns.load_dataset('penguins')

# Display the first few rows of the dataset
print(penguins.head())

# Create a pair plot using Seaborn
sns.pairplot(penguins, hue='species', height=2.5)

# Set plot title
plt.suptitle('Pair Plot of Penguin Data by Species', y=1.02)

# Show the plot
plt.show()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
import seaborn as sns
import matplotlib.pyplot as plt

penguins = sns.load_dataset('penguins')

# Create a pair plot with histograms on the diagonal
sns.pairplot(penguins, hue='species', height=2.5, diag_kind='hist')

# Set plot title
plt.suptitle('Pair Plot of Penguin Data by Species', y=1.02)

# Show the plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

penguins = sns.load_dataset('penguins')

print(penguins.head())

sns.pairplot(penguins, hue='species')
plt.show()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

penguins = sns.load_dataset('penguins')

print(penguins.head())

sns.scatterplot(x='bill_length_mm', y='bill_depth_mm', hue='species', data=penguins)
plt.title('Scatter Plot of Bill Length vs. Bill Depth')
plt.show()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

car_crashes = sns.load_dataset('car_crashes')

print(car_crashes.head())

sns.pairplot(car_crashes)
plt.show()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA
